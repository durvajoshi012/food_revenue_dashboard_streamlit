# %%
import pandas as pd

# %%
df = pd.read_excel("../data/Kitchen_data.xlsx", engine="openpyxl")

# %%
df.shape
# Out:
# (2100, 17)

# %%
df.head()
# Out:
#       MONTH       CITY         STORE    STATUS ZONE MAPPING  ORDER COUNT  \
# 0  Oct-2023  Ahmedabad  Ramos-Martin  Inactive         West        14270
# 1  Nov-2023  Ahmedabad  Ramos-Martin  Inactive         West         8528
# 2  Dec-2023  Ahmedabad  Ramos-Martin  Inactive         West        10798
# 3  Jan-2024  Ahmedabad  Ramos-Martin  Inactive         West         7804
# 4  Feb-2024  Ahmedabad  Ramos-Martin  Inactive         West        10060
#
#    CART SALES    DISCOUNT  NET REVENUE  IDEAL FOOD COST  GROSS MARGIN  \
# 0  6554333.68  1163493.98   5434068.17       1763679.62    3614747.39
# 1  2637625.82   636015.27   2146679.55        638415.30    1414249.00
# 2  4364193.67  1283840.18   3188606.71       1085080.58    2036999.44
# 3  3479969.32   854797.46   2734306.33       1180892.50    1451140.55
# 4  4771378.71  1290900.38   3602124.88       1114846.94    2394567.16
#
#    KITCHEN EBITDA  VARIANCE     REVENUE COHORT      CM COHORT EBITDA CATEGORY  \
# ...

# %%
df.columns
# Out:
# Index(['MONTH', 'CITY', 'STORE', 'STATUS', 'ZONE MAPPING', 'ORDER COUNT',
#        'CART SALES', 'DISCOUNT', 'NET REVENUE', 'IDEAL FOOD COST',
#        'GROSS MARGIN', 'KITCHEN EBITDA', 'VARIANCE', 'REVENUE COHORT',
#        'CM COHORT', 'EBITDA CATEGORY', 'EBITDA COHORT'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MONTH            2100 non-null   str
#  1   CITY             2100 non-null   str
#  2   STORE            2100 non-null   str
#  3   STATUS           2100 non-null   str
#  4   ZONE MAPPING     2100 non-null   str
#  5   ORDER COUNT      2100 non-null   int64
#  6   CART SALES       2100 non-null   float64
#  7   DISCOUNT         2100 non-null   float64
#  8   NET REVENUE      2100 non-null   float64
#  9   IDEAL FOOD COST  2100 non-null   float64
#  10  GROSS MARGIN     2100 non-null   float64
#  11  KITCHEN EBITDA   2100 non-null   float64
#  12  VARIANCE         2100 non-null   float64
#  13  REVENUE COHORT   2100 non-null   str
#  14  CM COHORT        2100 non-null   str
#  15  EBITDA CATEGORY  2100 non-null   str
#  16  EBITDA COHORT    2100 non-null   str
# ...

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# unique values 
df.nunique()
# Out:
# MONTH                 6
# CITY                  5
# STORE               344
# STATUS                2
# ZONE MAPPING          4
# ORDER COUNT        1835
# CART SALES         2100
# DISCOUNT           2100
# NET REVENUE        2100
# IDEAL FOOD COST    2100
# GROSS MARGIN       2100
# KITCHEN EBITDA     2100
# VARIANCE           2097
# REVENUE COHORT        3
# CM COHORT             3
# EBITDA CATEGORY       2
# EBITDA COHORT         3
# dtype: int64

# %%
df['STATUS'].unique()
# Out:
# <ArrowStringArray>
# ['Inactive', 'Active']
# Length: 2, dtype: str

# %%
##########################################################################################
# Column Understanding
##########################################################################################

# MONTH -> month-year
# STATUS -> active or inactive
# ZONE MAPPING -> Region
# ORDER COUNT -> total number of orders received
# CART SALES -> Total bill before discounts
# DISCOUNT -> Total discount given on orders
# NET REVENUE -> Final revenue earned (after discounts)
# IDEAL FOOD COST -> Estimated cost of food
# GROSS MARGIN -> Money left after food cost is removed
# EBITDA = Earnings Before Interest, Taxes, Depreciation, and Amortization
# KITCHEN EBITDA -> Overall profit/loss of the kitchen
# VARIANCE -> Difference between expected and actual performance
# REVENUE COHORT -> Grouping of stores based on revenue
# CM COHORT -> Grouping of stores based on contribution margin
# EBITDA CATEGORY -> Profitability category of the store
# EBITDA COHORT -> Grouping of stores based on EBITDA values

# %%
df['Date'] = pd.to_datetime(df['MONTH'], format='%b-%Y')
df['Date']
# Out:
# 0      2023-10-01
# 1      2023-11-01
# 2      2023-12-01
# 3      2024-01-01
# 4      2024-02-01
#           ...
# 2095   2023-11-01
# 2096   2023-12-01
# 2097   2024-01-01
# 2098   2024-02-01
# 2099   2024-03-01
# Name: Date, Length: 2100, dtype: datetime64[us]
